# %%
# Question 1 
# numpy 常用於數值/陣列運算, pandas 擅長資料格式的調整, matplotlib 擅長繪圖
import numpy as np
import matplotlib.pyplot as plt

# %%
w=3
b=0.5

x_lin = np.linspace(0,100,101) 
# np.linspace(0, 100, 101)是指 0~100 劃分成 101 個刻度(含頭尾), 所也就是 0, 1, 2,...,100 這 101 個數
# 這時候, x_lin 因為要記錄不只一個數, 因為 np.linspace() 傳回的是一個 Array, 所以 x_lin 就變成 Array 了

y=(x_lin + np.random.randn(101)*5)*w + b
# np.random.randn(101) 表示取樣了101次, 型態是 Array

plt.plot(x_lin , y , 'b.' ,label='data points')
# b. : b 就是 blue, 點(.) 就是最小單位的形狀
plt.title("Assune we have data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat = x_lin*w + b
plt.plot(x_lin , y , 'b.' , label='data')
plt.plot(x_lin , y_hat , 'r-' , label='prediction')
# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# 由def開頭, 依序是函數名稱 / 輸入值, 冒號(:)結尾
def mean_absolute_error(y,yp):
    """
    calculate MAE
    Args:
        y: 實際值
        yp: 預測值
    Return:
        mae: MAE
    """
    mae = MAE =sum(abs(y-yp))/len(y)
    return mae
MAE = mean_absolute_error(y , y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.284

# %%
def mean_square_error(y,yp):
    """
    calculate MSE
    Args:
         y: 實際值
        yp: 預測值
    Return:
        mse: MSE
    """
    mse = MSE =sum((y-yp)**2)/len(y)
    return mse
MSE = mean_square_error(y , y_hat)
print("The Mean square error is %.3f " % (MSE))
# Out:
# The Mean square error is 293.804

# %%
"""
Question 2
1.我選的是Quick, Draw! Doodle Recognition Challenge的競賽資料。人們在繪畫某一項物品時，若該物品同時具有多項特徵時，每個人對於各個特徵的注重程度不同而導致所畫出的圖案有些許差異，當人們依據圖案判斷時會去綜合考量，因此並不會因為不同人所畫出圖案的不同而認為說是不同的物品。此競賽主要是透過參賽者所畫出的各種圖案來訓練AI去判斷為何種物品，增加AI針對物品特徵的判斷能力。
2.資料來自於參加"Quick, Draw!"玩家所畫出的圖形。
3.資料型態為圖像。
4.評估方法為mean average precision , MAP
"""

# %%
"""
Question 3
1.核心問題:提升業績
定義:
(1)減少計程車到達目的地的時間，避開塞車路段
(2)根據各大眾運輸工具的旅客出站人數來安排計程車排班
2.資料來自於捷運、台鐵和高鐵的出站人數數據和交通相關政府部門的道路行駛速度數據
3.資料型態為數值
4.??
"""
